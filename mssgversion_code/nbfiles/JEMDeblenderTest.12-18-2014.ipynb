# %%
# %matplotlib inline

# %%
run 'mssg_makeDeblendingStudyPlots.py'    # orig
# Out:
# *********************** No e2 in output file, reading just the orig files
# vece1a_unbl =  [0.50086747893579864, 0.00045015612025329333, -0.49997177715113184]
#  Using file  deblendsOutput/deblendingTests_50runs.txt
# vece1a_unbl =  [0.49937141953750525, 0.00088764665635756353, -0.49964315285841143]
#  Using file  deblendsOutput/deblendingTests_50runs.txt
# vece1a_unbl =  [0.50124541745466822, 0.0011873282913064886, -0.50032336575609104]
#  Using file  deblendsOutput/deblendingTests_50runs.txt
# vece1b_unbl =  [0.5010345406118103, 0.001472206629287467, -0.50005777934907303]
# vece1b_unbl =  [0.50017643094720943, -0.00011991654457871981, -0.4982336974576842]
# vece1b_unbl =  [0.50058320105673448, 0.00042969733900186211, -0.50164148516907692]

# %%
run 'mssg_makeDeblendingStudyPlots.py'
# Out:
# *********************** No e2 in output file, reading just the orig files
# vece1a_unbl =  [0.49752232928745072, 7.8773930095836774e-05, -0.49943946526946681]
#  Using file  deblendsOutput/offsetBothOne200thPixelLeft_deblendingTests_50runs.txt
# vece1a_unbl =  [0.49971048846697513, -0.00018833950242163721, -0.49943802322662056]
#  Using file  deblendsOutput/offsetBothOne200thPixelLeft_deblendingTests_50runs.txt
# vece1a_unbl =  [0.50127213305908702, -1.6352266328436561e-05, -0.50093039881351076]
#  Using file  deblendsOutput/offsetBothOne200thPixelLeft_deblendingTests_50runs.txt
# vece1b_unbl =  [0.49952314900775285, -0.0012181707979556178, -0.499243693874169]
# vece1b_unbl =  [0.49991210740994663, -0.00062217212155621262, -0.50008398036478896]
# vece1b_unbl =  [0.49976694382362508, -0.0009367977474186251, -0.50115286559501004]

# %%
run 'mssg_makeDeblendingStudyPlots.py'   # -eps  and   + eps
# Out:
# *********************** No e2 in output file, reading just the orig files
# vece1a_unbl =  [0.50033436544714061, 0.00056578227884507943, -0.50007297073690893]
#  Using file  deblendsOutput/offsetLeftOne200thPixelLeftRightOne200thPixelRight_deblendingTests_50runs.txt
# vece1a_unbl =  [0.50002192825392233, 0.00053734066534351311, -0.50129776203755427]
#  Using file  deblendsOutput/offsetLeftOne200thPixelLeftRightOne200thPixelRight_deblendingTests_50runs.txt
# vece1a_unbl =  [0.5009587561749278, -0.00042546666418391554, -0.49900744448460316]
#  Using file  deblendsOutput/offsetLeftOne200thPixelLeftRightOne200thPixelRight_deblendingTests_50runs.txt
# vece1b_unbl =  [0.49907146425311255, 0.00057696164207230892, -0.50087415303348992]
# vece1b_unbl =  [0.49971279483372144, -0.0006458215549651669, -0.50020143426825292]
# vece1b_unbl =  [0.50038430317802263, 0.001568185226547445, -0.49971499413646653]

# %%
run 'mssg_makeDeblendingStudyPlots.py'
# Out:
# *********************** No e2 in output file, reading just the orig files
# vece1a_unbl =  [0.49789960012255591, 0.00044294531628395582, -0.50042965176240528]
#  Using file  deblendsOutput/offsetBothRandomHalfPixelLorR_deblendingTests_50runs.txt
# vece1a_unbl =  [0.5005072678105984, -1.3304398433806596e-05, -0.50014410140205778]
#  Using file  deblendsOutput/offsetBothRandomHalfPixelLorR_deblendingTests_50runs.txt
# vece1a_unbl =  [0.49989454339134098, -0.00096873305398518465, -0.50067318804719951]
#  Using file  deblendsOutput/offsetBothRandomHalfPixelLorR_deblendingTests_50runs.txt
# vece1b_unbl =  [0.5001697838748046, 0.00043823061034217183, -0.49891217201712124]
# vece1b_unbl =  [0.49915015261393747, -0.0011527422401528731, -0.50042970334665016]
# vece1b_unbl =  [0.5009308491629284, 0.0010389123640545006, -0.49992088830169784]

# %%
run 'mssg_makeDeblendingStudyPlots.py'
# Out:
# *********************** Has e2 in output file
# vece1a_unbl =  [0.50001932235983515, 0.0004325411598639284, -0.49872545968583837]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, 0.001)__peak_B_(1.0, 0.001)_50_runs.txt
# vece1a_unbl =  [0.50030805279532553, 0.0017195473505097181, -0.49961066834003987]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, 0.001)__peak_B_(1.0, 0.001)_50_runs.txt
# vece1a_unbl =  [0.49996622352213138, 0.00064422146023862753, -0.50096220331262598]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, 0.001)__peak_B_(1.0, 0.001)_50_runs.txt
# vece1b_unbl =  [0.49776711207135926, -0.0005429384891910005, -0.49937580588084524]
# vece1b_unbl =  [0.4992218685215572, 0.0011862605566403373, -0.49825761499384902]
# vece1b_unbl =  [0.49910086370331186, -0.00079296654735409476, -0.50184003913692909]

# %%
run 'mssg_makeDeblendingStudyPlots.py'
# Out:
# *********************** Has e2 in output file
# vece1a_unbl =  [0.50052722035698338, -0.00054668188834840594, -0.50096741844629822]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, -0.001)__peak_B_(1.0, -0.001)_50_runs.txt
# vece1a_unbl =  [0.50038630629009928, -0.00020078163183090636, -0.50158771375366717]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, -0.001)__peak_B_(1.0, -0.001)_50_runs.txt
# vece1a_unbl =  [0.49998557550969336, 0.0011688745905824361, -0.49963461731398923]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, -0.001)__peak_B_(1.0, -0.001)_50_runs.txt
# vece1b_unbl =  [0.50039136532221629, 0.00046332579050977873, -0.50089149583060011]
# vece1b_unbl =  [0.5001819895971974, 0.0016092853034433707, -0.49935725382485591]
# vece1b_unbl =  [0.50187741994656077, -0.00058840277091652736, -0.50032210596110005]

# %%
run 'mssg_makeRotMatchedtDeblendingPlots.py'
# Out:
# *********************** No e2 in output file, reading just the orig files
# vece1a_unbl =  [0.49892857246620798, 0.00144018455971336, -0.50059726040263142]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1, 0)__peak_B_(1, 0)_50_runsAndRandomOffsetHalfPixelEach.txt
# vece1a_deblresid =
#  [-0.023349291156762118, -0.042463702591614007, -0.054827141971150246]
# rotvece1a_deblresid =   [0.020222999886670975, 0.043022009332099168, 0.060881874324195666]
# vece1a_unbl =  [0.50173850073755688, 0.00094193909467017224, -0.50028100510748819]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1, 0)__peak_B_(1, 0)_50_runsAndRandomOffsetHalfPixelEach.txt
# vece1a_deblresid =
#  [-0.019438425160007225, -0.037666666785751347, -0.058697250227476516]
# rotvece1a_deblresid =   [0.017872333133709183, 0.042342051509069771, 0.05746631788007954]
# vece1a_unbl =  [0.49984345485188575, 0.00051210988359274179, -0.49994321285716053]
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1, 0)__peak_B_(1, 0)_50_runsAndRandomOffsetHalfPixelEach.txt
# vece1a_deblresid =
#  [-0.017613373941248046, -0.035135806439238318, -0.041336848680918969]
# rotvece1a_deblresid =   [0.015366122100097862, 0.034907725981025602, 0.043862001602073361]
# vece1b_unbl =  [0.50063174166571223, 0.0004094128149026477, -0.49942130494932668]
# vece1b_unbl =  [0.49901137629283665, 0.00026450341848811121, -0.49959367948291189]
# vece1b_unbl =  [0.50116909518899144, -0.00013080615032835086, -0.50019971228446125]
