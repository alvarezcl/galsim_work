# %%
# %matplotlib inline

# %%
 run 'mssg_makeDeblendingStudyPlots.py' # Center A and B exactly on grid at (-1,0) and (+1,0) resp ("Standard Centers")
# Out:
# *********************** Has e2 in output file
#  Using file  deblendsOutput/deblendingTests_peak_A_(-1.0, 0)__peak_B_(1.0, 0)_50_runs.InterpFlagFalse.txt
# vece1a_unbl =  [0.49962234936830285, 2.2201916129773737e-05, -0.49955804631471201]
# vece1a_unbl =
#  [0.5011480051766678, 0.00078041862765757311, -0.49997982548897651]
# vece1a_unbl =
#  [0.4998787610692032, -0.00025429187940791299, -0.49954660076257112]
# vece1b_unbl =
#  [0.50141675966377142, -0.0016157495069172945, -0.50001667557176055]
# vece1b_unbl =
#  [0.4994654995871271, -0.0010841109453819775, -0.49989557284419328]
# vece1b_unbl =
#  [0.49999316288623413, -0.00036957717785412791, -0.49851044792194926]

# %%
run 'mssg_makeDeblendingStudyPlots.py' # Shift A and B eps to the left off the Standard Centers
# Out:
# *********************** Has e2 in output file
# *********************** No e2 in output file, reading just the orig files
#  Using file  deblendsOutput/offsetBothOne200thPixelLeft_deblendingTests_50runs.txt
# vece1a_unbl =  [0.49752232928745072, 7.8773930095836774e-05, -0.49943946526946681]
# vece1a_unbl =
#  [0.49971048846697513, -0.00018833950242163721, -0.49943802322662056]
# vece1a_unbl =
#  [0.50127213305908702, -1.6352266328436561e-05, -0.50093039881351076]
# vece1b_unbl =
#  [0.49952314900775285, -0.0012181707979556178, -0.499243693874169]
# vece1b_unbl =
#  [0.49991210740994663, -0.00062217212155621262, -0.50008398036478896]
# vece1b_unbl =
#  [0.49976694382362508, -0.0009367977474186251, -0.50115286559501004]

# %%
run 'mssg_makeDeblendingStudyPlots.py' # Shift A and B eps to the right off the Standard Centers
# Out:
# *********************** Has e2 in output file
# *********************** No e2 in output file, reading just the orig files
#  Using file  deblendsOutput/offsetBothOne200thPixelRight_deblendingTests_50runs.txt
# vece1a_unbl =  [0.50030016471119165, 6.9442047659795669e-05, -0.5005265842984099]
# vece1a_unbl =
#  [0.50019247773722686, -5.068477179226871e-05, -0.50055625511442625]
# vece1a_unbl =
#  [0.50161639487163268, -0.00042316442684568577, -0.49870823260909491]
# vece1b_unbl =
#  [0.4999549494801046, -0.00038950111948944156, -0.5002536990485249]
# vece1b_unbl =
#  [0.50045605521386871, -0.00036943603684396419, -0.50165289231539889]
# vece1b_unbl =
#  [0.50128080704676348, -3.1937472800382947e-05, -0.49963428807330668]

# %%
run 'mssg_makeDeblendingStudyPlots.py'  # Shift A and B randomly up to half pixel L or R off the Standard Centers
# Out:
# *********************** Has e2 in output file
# *********************** No e2 in output file, reading just the orig files
#  Using file  deblendsOutput/offsetBothRandomHalfPixelLorR_deblendingTests_50runs.txt
# vece1a_unbl =  [0.49789960012255591, 0.00044294531628395582, -0.50042965176240528]
# vece1a_unbl =
#  [0.5005072678105984, -1.3304398433806596e-05, -0.50014410140205778]
# vece1a_unbl =
#  [0.49989454339134098, -0.00096873305398518465, -0.50067318804719951]
# vece1b_unbl =
#  [0.5001697838748046, 0.00043823061034217183, -0.49891217201712124]
# vece1b_unbl =
#  [0.49915015261393747, -0.0011527422401528731, -0.50042970334665016]
# vece1b_unbl =
#  [0.5009308491629284, 0.0010389123640545006, -0.49992088830169784]
